# %%
import numpy as np
import pandas as pd
import os
import math
import tensorflow as tf
import datetime

from sklearn.manifold import LocallyLinearEmbedding
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from keras import layers, models, activations
from pandas.tseries.offsets import DateOffset
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.saving import register_keras_serializable
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score
# Out:
# 2024-07-28 15:22:54.695856: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-28 15:22:54.715827: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-28 15:22:54.715844: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-28 15:22:54.715856: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-28 15:22:54.720271: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(tf.__version__)
print(tf.config.list_physical_devices())
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.set_visible_devices(gpus[0], 'GPU')
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
  except RuntimeError as e:
    print(e)
# Out:
# 2.14.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# 2 Physical GPUs, 1 Logical GPU
# 2024-07-28 15:22:55.662140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.662236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.665015: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.665116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.665186: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.665252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.666395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.666485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.666550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.705083: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.705184: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.705257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-28 15:22:55.705324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9807 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
# dirs
DATA_DIR = "./load.csv"
load_col = 'out.site_energy.total.energy_consumption.kwh'
# MW

# %%
if not os.path.exists("./model"):
    os.makedirs("./model")
if not os.path.exists("./training_history"):
    os.makedirs("./training_history")

# %%
data = pd.read_csv(DATA_DIR)
data['timestamp'] = pd.to_datetime(data['timestamp'])
data[load_col] = data[load_col] * 4 / 1e3
# MW

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data[load_col].to_numpy().reshape(-1, 1))
data[load_col] = data_scaled

# %%
SEED = 42
tf.keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()

# %%
data.describe()
# Out:
#        upgrade            timestamp  models_used  floor_area_represented  \
# count  35040.0                35040      35040.0            3.504000e+04
# mean      18.0  2018-07-02 12:07:30        535.0            2.933235e+08
# min       18.0  2018-01-01 00:15:00        535.0            2.933235e+08
# 25%       18.0  2018-04-02 06:11:15        535.0            2.933235e+08
# 50%       18.0  2018-07-02 12:07:30        535.0            2.933235e+08
# 75%       18.0  2018-10-01 18:03:45        535.0            2.933235e+08
# max       18.0  2019-01-01 00:00:00        535.0            2.933235e+08
# std        0.0                  NaN          0.0            5.960550e-08
#
#        out.district_cooling.cooling.energy_consumption.kwh  \
# count                                       35040.000000
# mean                                          351.077590
# min                                             0.000000
# 25%                                            56.488275
# 50%                                           259.402965
# 75%                                           574.228447
# max                                          1559.617664
# std                                           331.710202
#
#        out.district_heating.heating.energy_consumption.kwh  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.district_heating.water_systems.energy_consumption.kwh  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.electricity.cooling.energy_consumption.kwh  \
# count                                    35040.000000
# mean                                     10702.802560
# min                                        326.378723
# 25%                                       2706.386049
# 50%                                       7965.151518
# 75%                                      15479.805245
# max                                      55401.017935
# std                                       9898.426784
#
#        out.electricity.exterior_lighting.energy_consumption.kwh  \
# count                                       35040.000000
# mean                                         3606.591142
# min                                             0.000000
# 25%                                             0.000000
# 50%                                          3546.633502
# 75%                                          7127.583771
# max                                          7361.098134
# std                                          3564.157927
#
#        out.electricity.fans.energy_consumption.kwh  ...  \
# count                                 35040.000000  ...
# mean                                  20721.475338  ...
# min                                   16646.463233  ...
# 25%                                   19725.608356  ...
# 50%                                   20458.531255  ...
# 75%                                   21985.597167  ...
# max                                   24359.717506  ...
# std                                    1548.734876  ...
#
#        out.electricity.total.energy_consumption.kwh.savings  \
# count                                       35040.000000
# mean                                         4979.811962
# min                                        -28508.867274
# 25%                                          -529.918116
# 50%                                          2273.919309
# 75%                                          9286.504567
# max                                         40740.822629
# std                                          8136.228348
#
#        out.natural_gas.total.energy_consumption.kwh.savings  \
# count                                       35040.000000
# mean                                        23848.451624
# min                                           262.091277
# 25%                                          8719.805585
# 50%                                         18191.504378
# 75%                                         32494.864830
# max                                        159204.018407
# std                                         20711.247693
#
#        out.district_heating.cooling.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.natural_gas.cooling.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.other_fuel.cooling.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.other_fuel.heating.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.other_fuel.interior_equipment.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.other_fuel.total.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.other_fuel.water_systems.energy_consumption.kwh.savings  \
# count                                            35040.0
# mean                                                 0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
# std                                                  0.0
#
#        out.site_energy.total.energy_consumption.kwh.savings
# count                                       35040.000000
# mean                                        28859.420341
# min                                          3108.391514
# 25%                                         17223.696432
# 50%                                         23244.709423
# 75%                                         35158.530405
# max                                        136399.915739
# std                                         17025.161426
#
# [8 rows x 62 columns]

# %%
# Define a function to generate a list of timestamps every 2 hours within the dataset's range
def generate_timestamps(data) -> pd.DatetimeIndex:
    start = data['timestamp'].min() + DateOffset(days=3)
    end = data['timestamp'].max() - DateOffset(minutes=96*15)
    timestamps = pd.date_range(start=start, end=end, freq='15min')
    return timestamps

# %%
timestamps = generate_timestamps(data)
print(timestamps)
# Out:
# DatetimeIndex(['2018-01-04 00:15:00', '2018-01-04 00:30:00',
#                '2018-01-04 00:45:00', '2018-01-04 01:00:00',
#                '2018-01-04 01:15:00', '2018-01-04 01:30:00',
#                '2018-01-04 01:45:00', '2018-01-04 02:00:00',
#                '2018-01-04 02:15:00', '2018-01-04 02:30:00',
#                ...
#                '2018-12-30 21:45:00', '2018-12-30 22:00:00',
#                '2018-12-30 22:15:00', '2018-12-30 22:30:00',
#                '2018-12-30 22:45:00', '2018-12-30 23:00:00',
#                '2018-12-30 23:15:00', '2018-12-30 23:30:00',
#                '2018-12-30 23:45:00', '2018-12-31 00:00:00'],
#               dtype='datetime64[ns]', length=34656, freq='15min')

# %%
def generate_sets_for_all_timestamps(timestamps, data):
    training_sets = []
    change_rate_sets = []
    target_sets = []
    training_sets_time = []
    target_sets_time = []

    for timestamp in timestamps:
        # Calculate the range for the current period's data
        start_time_current = timestamp - DateOffset(days=2, hours=23, minutes=45)
        end_time_current = timestamp

        # Calculate the target range (the next 10 steps after the current timestamp)
        target_start_time = timestamp + DateOffset(minutes=15)
        target_end_time = timestamp + DateOffset(hours=0, minutes=96*15) 

        # Filter the data for training and target sets
        current_data = data[(data['timestamp'] >= start_time_current) & (data['timestamp'] <= end_time_current)]
        target_data = data[(data['timestamp'] >= target_start_time) & (data['timestamp'] <= target_end_time)]

        # Combine current and last week data for the training set
        training_data = pd.concat([current_data]).reset_index(drop=True)
        
        # Save the training and target sets
        if not training_data.empty and not target_data.empty:
            training_sets.append(training_data[load_col])
            target_sets.append(target_data[load_col])
            training_sets_time.append(list(training_data['timestamp']))
            target_sets_time.append(list(target_data['timestamp']))

    training_sets = np.array(training_sets)
    target_sets = np.array(target_sets)
    training_sets_time = np.array(training_sets_time)
    target_sets_time = np.array(target_sets_time)

    return training_sets, target_sets, training_sets_time, target_sets_time

# %%
# Generate training and target sets for all the timestamps
training_sets, target_sets, training_sets_time, target_sets_time = generate_sets_for_all_timestamps(timestamps, data)

# %%
MONTH_TIME_STEP = math.floor(timestamps.shape[0] / 24)
X_test = []
y_test = []
X_test_time = []
y_test_time = []
minList = []
maxList = []
for i in range(0, 24):
    min = (i+1)*MONTH_TIME_STEP-(192*(i+1))
    max = (i+1)*MONTH_TIME_STEP-(192*i)
    X_test.append(training_sets[min:max])
    y_test.append(target_sets[min:max])
    X_test_time.append(training_sets_time[min:max])
    y_test_time.append(target_sets_time[min:max])
    training_sets = np.concatenate([training_sets[:min], training_sets[max:]])
    target_sets = np.concatenate([target_sets[:min], target_sets[max:]])
    training_sets_time = np.concatenate([training_sets_time[:min], training_sets_time[max:]])
    target_sets_time = np.concatenate([target_sets_time[:min], target_sets_time[max:]])

# %%
X_test = np.concatenate([i for i in X_test])
y_test = np.concatenate([i for i in y_test])
X_test_time = np.concatenate([i for i in X_test_time])
y_test_time = np.concatenate([i for i in y_test_time])

# %%
X_train = training_sets
y_train = target_sets
X_train_time = training_sets_time
y_train_time = target_sets_time

# %%
print(np.array(X_train).shape)
print(np.array(X_test).shape)
print(np.array(y_train).shape)
print(np.array(y_test).shape)
# Out:
# (30048, 288)
# (4608, 288)
# (30048, 96)
# (4608, 96)

# %%
# pca params
n_components_reduce = 24
n_components_reconst = 8

# %%
pca_reduce = PCA(n_components=n_components_reduce)
pca_reconst = PCA(n_components=n_components_reconst)

# %%
X_train_reduce = pca_reduce.fit_transform(X_train)
X_test_reduce = pca_reduce.transform(X_test)
y_train_reduce = pca_reconst.fit_transform(y_train)
y_test_reconst = pca_reconst.transform(y_test)

# %%
X_train_reduce = X_train_reduce.reshape(*X_train_reduce.shape, 1)
X_test_reduce = X_test_reduce.reshape(*X_test_reduce.shape, 1)
y_train_reduce = y_train_reduce.reshape(*y_train_reduce.shape, 1)
y_test_reconst = y_test_reconst.reshape(*y_test_reconst.shape, 1)

# %%
n_samples = X_train_reduce.shape[0]
past_timesteps = X_train_reduce.shape[1]
future_timesteps = y_train_reduce.shape[1]
feature_dim = 1
latent_dim = 50

# %%
input = layers.Input(shape=(past_timesteps, feature_dim))
x = layers.LSTM(units=latent_dim, return_sequences=False)(input)
ouput = layers.Dense(future_timesteps)(x)


model = models.Model(input, ouput)
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 24, 1)]           0
#
#  lstm (LSTM)                 (None, 50)                10400
#
#  dense (Dense)               (None, 8)                 408
#
# =================================================================
# Total params: 10808 (42.22 KB)
# Trainable params: 10808 (42.22 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %load_ext tensorboard

tensorboard_callback = TensorBoard(logdir, histogram_freq=1)
early_stopping_callback = EarlyStopping(monitor="loss", patience=10, min_delta=5e-5)
reduce_lr_callback = ReduceLROnPlateau(monitor="loss", factor=0.3, patience=5, verbose=1, min_lr=1e-7)
callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback]

# %%
history = model.fit(
    X_train_reduce,
    y_train_reduce,
    verbose=1,
    epochs=200,
    batch_size=96,
    callbacks=[tensorboard_callback, early_stopping_callback, reduce_lr_callback]
)
# Out:
# Epoch 1/200
# 2024-07-28 15:23:47.320965: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2024-07-28 15:23:47.495697: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f7a1192ee30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-28 15:23:47.495713: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-07-28 15:23:47.498059: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#  66/313 [=====>........................] - ETA: 0s - loss: 0.3407
# 2024-07-28 15:23:47.559660: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 [==============================] - 2s 2ms/step - loss: 0.3104 - lr: 0.0010
# Epoch 2/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2493 - lr: 0.0010
# Epoch 3/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2036 - lr: 0.0010
# Epoch 4/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1811 - lr: 0.0010
# Epoch 5/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1664 - lr: 0.0010
# Epoch 6/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1539 - lr: 0.0010
# Epoch 7/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1431 - lr: 0.0010
# Epoch 8/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1332 - lr: 0.0010
# Epoch 9/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1207 - lr: 0.0010
# Epoch 10/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1100 - lr: 0.0010
# Epoch 11/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0989 - lr: 0.0010
# Epoch 12/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0864 - lr: 0.0010
# Epoch 13/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0782 - lr: 0.0010
# Epoch 14/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0709 - lr: 0.0010
# Epoch 15/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0629 - lr: 0.0010
# Epoch 16/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0581 - lr: 0.0010
# Epoch 17/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0545 - lr: 0.0010
# Epoch 18/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0521 - lr: 0.0010
# Epoch 19/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0471 - lr: 0.0010
# Epoch 20/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0453 - lr: 0.0010
# Epoch 21/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0428 - lr: 0.0010
# Epoch 22/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0394 - lr: 0.0010
# Epoch 23/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0379 - lr: 0.0010
# Epoch 24/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0362 - lr: 0.0010
# Epoch 25/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0372 - lr: 0.0010
# Epoch 26/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0352 - lr: 0.0010
# Epoch 27/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0351 - lr: 0.0010
# Epoch 28/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0304 - lr: 0.0010
# Epoch 29/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0300 - lr: 0.0010
# Epoch 30/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0294 - lr: 0.0010
# Epoch 31/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0284 - lr: 0.0010
# Epoch 32/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0273 - lr: 0.0010
# Epoch 33/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0283 - lr: 0.0010
# Epoch 34/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0254 - lr: 0.0010
# Epoch 35/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0269 - lr: 0.0010
# Epoch 36/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0240 - lr: 0.0010
# Epoch 37/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0256 - lr: 0.0010
# Epoch 38/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0240 - lr: 0.0010
# Epoch 39/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0227 - lr: 0.0010
# Epoch 40/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0248 - lr: 0.0010
# Epoch 41/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0219 - lr: 0.0010
# Epoch 42/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0209 - lr: 0.0010
# Epoch 43/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0214 - lr: 0.0010
# Epoch 44/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0215 - lr: 0.0010
# Epoch 45/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0200 - lr: 0.0010
# Epoch 46/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0198 - lr: 0.0010
# Epoch 47/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0190 - lr: 0.0010
# Epoch 48/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0194 - lr: 0.0010
# Epoch 49/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0188 - lr: 0.0010
# Epoch 50/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0181 - lr: 0.0010
# Epoch 51/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0190 - lr: 0.0010
# Epoch 52/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0183 - lr: 0.0010
# Epoch 53/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0182 - lr: 0.0010
# Epoch 54/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0236 - lr: 0.0010
# Epoch 55/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0169 - lr: 0.0010
# Epoch 56/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0167 - lr: 0.0010
# Epoch 57/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0159 - lr: 0.0010
# Epoch 58/200
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0160 - lr: 0.0010
# Epoch 59/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0158 - lr: 0.0010
# Epoch 60/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0154 - lr: 0.0010
# Epoch 61/200
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0153 - lr: 0.0010
# Epoch 62/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0161 - lr: 0.0010
# Epoch 63/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0146 - lr: 0.0010
# Epoch 64/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0148 - lr: 0.0010
# Epoch 65/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0155 - lr: 0.0010
# Epoch 66/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0142 - lr: 0.0010
# Epoch 67/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0234 - lr: 0.0010
# Epoch 68/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0139 - lr: 0.0010
# Epoch 69/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0139 - lr: 0.0010
# Epoch 70/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0136 - lr: 0.0010
# Epoch 71/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0175 - lr: 0.0010
# Epoch 72/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0136 - lr: 0.0010
# Epoch 73/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0134 - lr: 0.0010
# Epoch 74/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0132 - lr: 0.0010
# Epoch 75/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0148 - lr: 0.0010
# Epoch 76/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0127 - lr: 0.0010
# Epoch 77/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0150 - lr: 0.0010
# Epoch 78/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0128 - lr: 0.0010
# Epoch 79/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0131 - lr: 0.0010
# Epoch 80/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0138 - lr: 0.0010
# Epoch 81/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0120 - lr: 0.0010
# Epoch 82/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0143 - lr: 0.0010
# Epoch 83/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0122 - lr: 0.0010
# Epoch 84/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0119 - lr: 0.0010
# Epoch 85/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0119 - lr: 0.0010
# Epoch 86/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0144 - lr: 0.0010
# Epoch 87/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0124 - lr: 0.0010
# Epoch 88/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0174 - lr: 0.0010
# Epoch 89/200
# 304/313 [============================>.] - ETA: 0s - loss: 0.0206
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0203 - lr: 0.0010
# Epoch 90/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0136 - lr: 3.0000e-04
# Epoch 91/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0132 - lr: 3.0000e-04
# Epoch 92/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0113 - lr: 3.0000e-04
# Epoch 93/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0110 - lr: 3.0000e-04
# Epoch 94/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0109 - lr: 3.0000e-04
# Epoch 95/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0107 - lr: 3.0000e-04
# Epoch 96/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0107 - lr: 3.0000e-04
# Epoch 97/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0106 - lr: 3.0000e-04
# Epoch 98/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0105 - lr: 3.0000e-04
# Epoch 99/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0105 - lr: 3.0000e-04
# Epoch 100/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0119 - lr: 3.0000e-04
# Epoch 101/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0118 - lr: 3.0000e-04
# Epoch 102/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0103 - lr: 3.0000e-04
# Epoch 103/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0102 - lr: 3.0000e-04
# Epoch 104/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0103 - lr: 3.0000e-04
# Epoch 105/200
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0101 - lr: 3.0000e-04
# Epoch 106/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0101 - lr: 3.0000e-04
# Epoch 107/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0101 - lr: 3.0000e-04
# Epoch 108/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0114 - lr: 3.0000e-04
# Epoch 109/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0101 - lr: 3.0000e-04
# Epoch 110/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0100 - lr: 3.0000e-04
# Epoch 111/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0113 - lr: 3.0000e-04
# Epoch 112/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0111 - lr: 3.0000e-04
# Epoch 113/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0099 - lr: 3.0000e-04
# Epoch 114/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0098 - lr: 3.0000e-04
# Epoch 115/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0098 - lr: 3.0000e-04
# Epoch 116/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0110 - lr: 3.0000e-04
# Epoch 117/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0097 - lr: 3.0000e-04
# Epoch 118/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0097 - lr: 3.0000e-04
# Epoch 119/200
# 291/313 [==========================>...] - ETA: 0s - loss: 0.0110
# Epoch 119: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0109 - lr: 3.0000e-04
# Epoch 120/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0093 - lr: 9.0000e-05
# Epoch 121/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0093 - lr: 9.0000e-05
# Epoch 122/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0093 - lr: 9.0000e-05
# Epoch 123/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0093 - lr: 9.0000e-05
# Epoch 124/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0093 - lr: 9.0000e-05
# Epoch 125/200
# 310/313 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 125: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0092 - lr: 9.0000e-05
# Epoch 126/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.7000e-05
# Epoch 127/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.7000e-05
# Epoch 128/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0092 - lr: 2.7000e-05
# Epoch 129/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.7000e-05
# Epoch 130/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0104 - lr: 2.7000e-05
# Epoch 131/200
# 296/313 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 131: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.7000e-05
# Epoch 132/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 8.1000e-06
# Epoch 133/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 8.1000e-06
# Epoch 134/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 8.1000e-06
# Epoch 135/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 8.1000e-06
# Epoch 136/200
# 298/313 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 136: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 8.1000e-06
# Epoch 137/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0101 - lr: 2.4300e-06
# Epoch 138/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.4300e-06
# Epoch 139/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.4300e-06
# Epoch 140/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.4300e-06
# Epoch 141/200
# 293/313 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 141: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 2.4300e-06
# Epoch 142/200
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0091 - lr: 7.2900e-07

# %%
y_pred_reduce = model.predict(X_test_reduce)
y_pred = pca_reconst.inverse_transform(y_pred_reduce)
# Out:
# 144/144 [==============================] - 0s 620us/step

# %%
print(y_test.shape)
print(y_pred.shape)

mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("-" * 86)
print(f'mse: {mse:.4f}')
print(f'rmse: {rmse:.4f}')
print(f'mae: {mae:.4f}')
print(f'mape: {mape: .4f}')
print(f'r2: {r2:.4f}')
print("-" * 86)

y_test_inv = scaler.inverse_transform(y_test)
y_pred_inv = scaler.inverse_transform(y_pred)


mse_inv = mean_squared_error(y_test_inv, y_pred_inv)
rmse_inv = math.sqrt(mse_inv)
mae_inv = mean_absolute_error(y_test_inv, y_pred_inv)
mape_inv = mean_absolute_percentage_error(y_test_inv, y_pred_inv)
r2_inv = r2_score(y_test_inv, y_pred_inv)

print("-" * 86)
print(f'mse_inv: {mse_inv:.4f}')
print(f'rmse_inv: {rmse_inv:.4f}')
print(f'mae_inv: {mae_inv:.4f}')
print(f'mape_inv: {mape_inv: .4f}')
print(f'r2_inv: {r2_inv:.4f}')
print("-" * 86)
# Out:
# (4608, 96)
# (4608, 96)
# --------------------------------------------------------------------------------------
# mse: 0.0345
# rmse: 0.1857
# mae: 0.1363
# mape:  0.5769
# r2: -0.1477
# --------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------
# mse_inv: 7018.7677
# rmse_inv: 83.7781
# mae_inv: 61.4812
# mape_inv:  0.1602
# r2_inv: -0.1477
# --------------------------------------------------------------------------------------

# %%
RESULT_DIR = "./result/"
result_df = pd.DataFrame(y_pred)
# result_df.to_csv(RESULT_DIR+"pca-LSTM_96steps.csv")
